# %%
from rmgpy.rmg.output import *
from rmgpy.chemkin import *

# %%
speciesList, reactionList = loadChemkinFile('files/chem_annotated.inp','files/species_dictionary.txt')

# %%
time, data = parseCSVData('files/simulation_1_19.csv')

# %%
% matplotlib inline

# %%
plotGenericData('plot.png',xVar=time,yVar=[data[0]])

# %%
plotSimulation('files/simulation_1_19.csv', numSpecies=5)

# %%
plotSimulation('files/simulation_1_19.csv', species={'ethyl radical':'C2H5(3)', 'ethane': 'ethane(1)','H2':'H2(12)'})
