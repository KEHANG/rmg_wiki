# %%
from rmgpy.chemkin import *
from rmgpy.tools.plot import *

# %%
s = SimulationPlot(csvFile='files/simulation_1_19.csv')
s.load()
t = SimulationPlot(csvFile='files/simulation_1_16.csv', numSpecies=10)
t.load()
t.comparePlot(s)

# %%
speciesList, reactionList = loadChemkinFile('files/chem_annotated.inp','files/species_dictionary.txt')

# %%
time, data = parseCSVData('files/simulation_1_19.csv')

# %%
% matplotlib inline

# %%
GenericPlot(xVar=time,yVar=[data[0]]).plot('plot.png')
print data[5].label
print data[5].index
print data[5].species
print data[1].species
# Out:
# ethane(1)
# 1
# ethane
# None

# %%
SimulationPlot(csvFile='files/simulation_1_19.csv', numSpecies=5).plot()

# %%
SimulationPlot(csvFile='files/simulation_1_19.csv', species={'ethyl radical':'C2H5(3)', 'ethane': 'ethane(1)','H2':'H2(12)'}).plot()

# %%
GenericPlot(yVar=[data[3],data[0]]).barplot()
