# %%
from rmgpy.rmg.main import RMG
from rmgpy.rmg.model import CoreEdgeReactionModel
from rmgpy import settings
from IPython.display import display

# %% [markdown]
# ## Create the most basic RMG() object that can generate reactions

# %%
# Create input file
# Here you can change the thermo and reaction libraries, or restrict families.  
input_header = """
database(
    thermoLibraries = ['KlippensteinH2O2','primaryThermoLibrary','DFT_QCI_thermo','CBS_QB3_1dHR'],
    reactionLibraries = [],  
    seedMechanisms = [],
    kineticsDepositories = 'default', 
    #this section lists possible reaction families to find reactioons with
    kineticsFamilies = ['R_Recombination'],
    kineticsEstimator = 'rate rules',
)
"""

# %%
speciesList = """
# List all species you want reactions between
species(
    label='ethane',
    reactive=True,
    structure=SMILES("CC"),
)

species(
    label='H',
    reactive=True,
    structure=SMILES("[H]"),
)

species(
    label='butane',
    reactive=True,
    structure=SMILES("CCCC"),
)
"""

# %%
# Write input file to disk
inputFile = open('scratch/input.py','w')
inputFile.write(input_header)
inputFile.write(speciesList)
inputFile.close()

# %%
# Execute generate reactions
from rmgpy.tools.generate_reactions import *
rmg = RMG()
rmg = execute(rmg,'scratch/input.py','scratch')

# %%
from rmgpy.cantherm.output import prettify
for rxn in rmg.reactionModel.outputReactionList:
    display(rxn)
    print prettify(repr(rxn.kinetics))
# Out:
# Reaction(index=1, reactants=[Species(index=4, label="[CH3]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.94801,0.000827594,8.34934e-06,-9.82638e-09,3.80106e-12,16425.4,0.336653], Tmin=(100,'K'), Tmax=(660.45,'K')), NASAPolynomial(coeffs=[3.2217,0.00522646,-1.64125e-06,2.58224e-10,-1.62579e-14,16521.3,3.53938], Tmin=(660.45,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(136.55,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(136.55,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH3]")], transportData=TransportData(shapeIndex=2, epsilon=(1197.29,'J/mol'), sigma=(3.8,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(15.0345,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=4, label="[CH3]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.94801,0.000827594,8.34934e-06,-9.82638e-09,3.80106e-12,16425.4,0.336653], Tmin=(100,'K'), Tmax=(660.45,'K')), NASAPolynomial(coeffs=[3.2217,0.00522646,-1.64125e-06,2.58224e-10,-1.62579e-14,16521.3,3.53938], Tmin=(660.45,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(136.55,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(136.55,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH3]")], transportData=TransportData(shapeIndex=2, epsilon=(1197.29,'J/mol'), sigma=(3.8,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(15.0345,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=1, label="ethane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.74674,4.51426e-05,4.07975e-05,-4.5743e-08,1.5685e-11,-11474.1,4.7413], Tmin=(100,'K'), Tmax=(981.6,'K')), NASAPolynomial(coeffs=[3.34693,0.0161751,-6.00969e-06,1.09624e-09,-7.72316e-14,-12094.2,3.1042], Tmin=(981.6,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-95.5174,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-95.5174,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CC")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(30.069,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(8.26e+17,'cm^3/(mol*s)'), n=-1.4, Ea=(4.184,'kJ/mol'), T0=(1,'K'), Tmin=(300,'K'), Tmax=(2000,'K'), comment="""Exact match found for rate rule (C_methyl;C_methyl)"""), pairs=[(Species(index=4, label="[CH3]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.94801,0.000827594,8.34934e-06,-9.82638e-09,3.80106e-12,16425.4,0.336653], Tmin=(100,'K'), Tmax=(660.45,'K')), NASAPolynomial(coeffs=[3.2217,0.00522646,-1.64125e-06,2.58224e-10,-1.62579e-14,16521.3,3.53938], Tmin=(660.45,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(136.55,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(136.55,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH3]")], transportData=TransportData(shapeIndex=2, epsilon=(1197.29,'J/mol'), sigma=(3.8,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(15.0345,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=1, label="ethane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.74674,4.51426e-05,4.07975e-05,-4.5743e-08,1.5685e-11,-11474.1,4.7413], Tmin=(100,'K'), Tmax=(981.6,'K')), NASAPolynomial(coeffs=[3.34693,0.0161751,-6.00969e-06,1.09624e-09,-7.72316e-14,-12094.2,3.1042], Tmin=(981.6,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-95.5174,'kJ/mol'), comment="""Ther ...
# Arrhenius(
#     A = (8.26e+17, 'cm^3/(mol*s)'),
#     n = -1.4,
#     Ea = (4.184, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (300, 'K'),
#     Tmax = (2000, 'K'),
#     comment = 'Exact match found for rate rule (C_methyl;C_methyl)',
# )
# Reaction(index=2, reactants=[Species(index=5, label="C[CH2]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.69276,0.00187276,3.11951e-05,-3.71212e-08,1.32027e-11,13168.3,7.07155], Tmin=(100,'K'), Tmax=(967.563,'K')), NASAPolynomial(coeffs=[4.21409,0.0122658,-4.37068e-06,7.87987e-10,-5.5604e-14,12480.1,1.53827], Tmin=(967.563,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(109.359,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(109.359,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH2]")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(29.0611,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=1, label="ethane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.74674,4.51426e-05,4.07975e-05,-4.5743e-08,1.5685e-11,-11474.1,4.7413], Tmin=(100,'K'), Tmax=(981.6,'K')), NASAPolynomial(coeffs=[3.34693,0.0161751,-6.00969e-06,1.09624e-09,-7.72316e-14,-12094.2,3.1042], Tmin=(981.6,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-95.5174,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-95.5174,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CC")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(30.069,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(1e+14,'cm^3/(mol*s)','+|-',1e+13), n=0, Ea=(0,'kJ/mol'), T0=(1,'K'), Tmin=(298,'K'), comment="""Exact match found for rate rule (C_rad/H2/Cs;H_rad)"""), pairs=[(Species(index=5, label="C[CH2]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.69276,0.00187276,3.11951e-05,-3.71212e-08,1.32027e-11,13168.3,7.07155], Tmin=(100,'K'), Tmax=(967.563,'K')), NASAPolynomial(coeffs=[4.21409,0.0122658,-4.37068e-06,7.87987e-10,-5.5604e-14,12480.1,1.53827], Tmin=(967.563,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(109.359,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(109.359,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH2]")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(29.0611,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=1, label="ethane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.74674,4.51426e-05,4.07975e-05,-4.5743e-08,1.5685e-11,-11474.1,4.7413], Tmin=(100,'K'), Tmax=(981.6,'K')), NASAPolynomial(coeffs=[3.34693,0.0161751,-6.00969e-06,1.09624e-09,-7.72316e-14,-12094.2,3.1042], Tmin=(981.6,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-95.5174,'kJ/mol'), comment="""Thermo l ...
# Arrhenius(
#     A = (1e+14, 'cm^3/(mol*s)', '+|-', 1e+13),
#     n = 0,
#     Ea = (0, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (298, 'K'),
#     comment = 'Exact match found for rate rule (C_rad/H2/Cs;H_rad)',
# )
# Reaction(index=3, reactants=[Species(index=5, label="C[CH2]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.69276,0.00187276,3.11951e-05,-3.71212e-08,1.32027e-11,13168.3,7.07155], Tmin=(100,'K'), Tmax=(967.563,'K')), NASAPolynomial(coeffs=[4.21409,0.0122658,-4.37068e-06,7.87987e-10,-5.5604e-14,12480.1,1.53827], Tmin=(967.563,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(109.359,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(109.359,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH2]")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(29.0611,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=5, label="C[CH2]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.69276,0.00187276,3.11951e-05,-3.71212e-08,1.32027e-11,13168.3,7.07155], Tmin=(100,'K'), Tmax=(967.563,'K')), NASAPolynomial(coeffs=[4.21409,0.0122658,-4.37068e-06,7.87987e-10,-5.5604e-14,12480.1,1.53827], Tmin=(967.563,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(109.359,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(109.359,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH2]")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(29.0611,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1147.61,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-144.017,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-144.017,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CCCC")], transportData=TransportData(shapeIndex=2, epsilon=(2896.88,'J/mol'), sigma=(5.41451,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0, comment="""Epsilon & sigma estimated with Tc=452.49 K, Pc=41.41 bar (from Joback method)"""), molecularWeight=(58.1222,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(1.15e+13,'cm^3/(mol*s)','*|/',2), n=0, Ea=(0,'kJ/mol'), T0=(1,'K'), Tmin=(300,'K'), Tmax=(1200,'K'), comment="""Exact match found for rate rule (C_rad/H2/Cs;C_rad/H2/Cs)"""), pairs=[(Species(index=5, label="C[CH2]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.69276,0.00187276,3.11951e-05,-3.71212e-08,1.32027e-11,13168.3,7.07155], Tmin=(100,'K'), Tmax=(967.563,'K')), NASAPolynomial(coeffs=[4.21409,0.0122658,-4.37068e-06,7.87987e-10,-5.5604e-14,12480.1,1.53827], Tmin=(967.563,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(109.359,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(109.359,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH2]")], transportData=TransportData(shapeIndex=2, epsilon=(2097.75,'J/mol'), sigma=(4.302,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.5, comment="""GRI-Mech"""), molecularWeight=(29.0611,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], T ...
# Arrhenius(
#     A = (1.15e+13, 'cm^3/(mol*s)', '*|/', 2),
#     n = 0,
#     Ea = (0, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (300, 'K'),
#     Tmax = (1200, 'K'),
#     comment = 'Exact match found for rate rule (C_rad/H2/Cs;C_rad/H2/Cs)',
# )
# Reaction(index=4, reactants=[Species(index=4, label="[CH3]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.94801,0.000827594,8.34934e-06,-9.82638e-09,3.80106e-12,16425.4,0.336653], Tmin=(100,'K'), Tmax=(660.45,'K')), NASAPolynomial(coeffs=[3.2217,0.00522646,-1.64125e-06,2.58224e-10,-1.62579e-14,16521.3,3.53938], Tmin=(660.45,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(136.55,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(136.55,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH3]")], transportData=TransportData(shapeIndex=2, epsilon=(1197.29,'J/mol'), sigma=(3.8,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(15.0345,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=6, label="[CH2]CC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.02812,0.0147027,2.40497e-05,-3.66721e-08,1.38604e-11,10512.1,12.47], Tmin=(100,'K'), Tmax=(984.476,'K')), NASAPolynomial(coeffs=[6.16555,0.0184493,-6.79018e-06,1.23046e-09,-8.63844e-14,9095.01,-6.67672], Tmin=(984.476,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(87.0621,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(87.0621,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH2]CC")], transportData=TransportData(shapeIndex=2, epsilon=(2218.31,'J/mol'), sigma=(4.982,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(43.0877,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1147.61,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-144.017,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-144.017,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CCCC")], transportData=TransportData(shapeIndex=2, epsilon=(2896.88,'J/mol'), sigma=(5.41451,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0, comment="""Epsilon & sigma estimated with Tc=452.49 K, Pc=41.41 bar (from Joback method)"""), molecularWeight=(58.1222,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(3.37e+13,'cm^3/(mol*s)','*|/',2), n=0, Ea=(0,'kJ/mol'), T0=(1,'K'), Tmin=(300,'K'), Tmax=(2000,'K'), comment="""Exact match found for rate rule (C_rad/H2/Cs;C_methyl)"""), pairs=[(Species(index=6, label="[CH2]CC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.02812,0.0147027,2.40497e-05,-3.66721e-08,1.38604e-11,10512.1,12.47], Tmin=(100,'K'), Tmax=(984.476,'K')), NASAPolynomial(coeffs=[6.16555,0.0184493,-6.79018e-06,1.23046e-09,-8.63844e-14,9095.01,-6.67672], Tmin=(984.476,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(87.0621,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(87.0621,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH2]CC")], transportData=TransportData(shapeIndex=2, epsilon=(2218.31,'J/mol'), sigma=(4.982,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(43.0877,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1 ...
# Arrhenius(
#     A = (3.37e+13, 'cm^3/(mol*s)', '*|/', 2),
#     n = 0,
#     Ea = (0, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (300, 'K'),
#     Tmax = (2000, 'K'),
#     comment = 'Exact match found for rate rule (C_rad/H2/Cs;C_methyl)',
# )
# Reaction(index=5, reactants=[Species(index=7, label="C[CH]CC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.48181,0.0270988,1.03882e-05,-2.36644e-08,8.65252e-12,6369.62,17.2943], Tmin=(100,'K'), Tmax=(1083.85,'K')), NASAPolynomial(coeffs=[6.12705,0.0282085,-1.13016e-05,2.0733e-09,-1.4345e-13,4724.07,-4.53131], Tmin=(1083.85,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(52.4618,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(52.4618,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH]CC")], transportData=TransportData(shapeIndex=2, epsilon=(2968.28,'J/mol'), sigma=(5.176,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(57.1143,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1147.61,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-144.017,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-144.017,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CCCC")], transportData=TransportData(shapeIndex=2, epsilon=(2896.88,'J/mol'), sigma=(5.41451,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0, comment="""Epsilon & sigma estimated with Tc=452.49 K, Pc=41.41 bar (from Joback method)"""), molecularWeight=(58.1222,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(2e+13,'cm^3/(mol*s)','*|/',3.16), n=0, Ea=(0,'kJ/mol'), T0=(1,'K'), Tmin=(300,'K'), Tmax=(2000,'K'), comment="""Exact match found for rate rule (C_rad/H/NonDeC;H_rad)"""), pairs=[(Species(index=7, label="C[CH]CC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.48181,0.0270988,1.03882e-05,-2.36644e-08,8.65252e-12,6369.62,17.2943], Tmin=(100,'K'), Tmax=(1083.85,'K')), NASAPolynomial(coeffs=[6.12705,0.0282085,-1.13016e-05,2.0733e-09,-1.4345e-13,4724.07,-4.53131], Tmin=(1083.85,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(52.4618,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(52.4618,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="C[CH]CC")], transportData=TransportData(shapeIndex=2, epsilon=(2968.28,'J/mol'), sigma=(5.176,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(57.1143,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=( ...
# Arrhenius(
#     A = (2e+13, 'cm^3/(mol*s)', '*|/', 3.16),
#     n = 0,
#     Ea = (0, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (300, 'K'),
#     Tmax = (2000, 'K'),
#     comment = 'Exact match found for rate rule (C_rad/H/NonDeC;H_rad)',
# )
# Reaction(index=6, reactants=[Species(index=8, label="[CH2]CCC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.25388,0.0316764,2.89968e-06,-1.98045e-08,8.20489e-12,7652.64,17.2725], Tmin=(100,'K'), Tmax=(1050.58,'K')), NASAPolynomial(coeffs=[7.59594,0.0260842,-1.01718e-05,1.85188e-09,-1.28169e-13,5716.36,-12.6368], Tmin=(1050.58,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(63.0573,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(63.0573,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH2]CCC")], transportData=TransportData(shapeIndex=2, epsilon=(2968.28,'J/mol'), sigma=(5.176,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(57.1143,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1147.61,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-144.017,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(-144.017,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="CCCC")], transportData=TransportData(shapeIndex=2, epsilon=(2896.88,'J/mol'), sigma=(5.41451,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0, comment="""Epsilon & sigma estimated with Tc=452.49 K, Pc=41.41 bar (from Joback method)"""), molecularWeight=(58.1222,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(1e+14,'cm^3/(mol*s)','+|-',1e+13), n=0, Ea=(0,'kJ/mol'), T0=(1,'K'), Tmin=(298,'K'), comment="""Exact match found for rate rule (C_rad/H2/Cs;H_rad)"""), pairs=[(Species(index=8, label="[CH2]CCC", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.25388,0.0316764,2.89968e-06,-1.98045e-08,8.20489e-12,7652.64,17.2725], Tmin=(100,'K'), Tmax=(1050.58,'K')), NASAPolynomial(coeffs=[7.59594,0.0260842,-1.01718e-05,1.85188e-09,-1.28169e-13,5716.36,-12.6368], Tmin=(1050.58,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(63.0573,'kJ/mol'), comment="""Thermo library: DFT_QCI_thermo"""), conformer=Conformer(E0=(63.0573,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[CH2]CCC")], transportData=TransportData(shapeIndex=2, epsilon=(2968.28,'J/mol'), sigma=(5.176,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=1.0, comment="""GRI-Mech"""), molecularWeight=(57.1143,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=3, label="butane", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.16918,0.0343905,-1.61589e-06,-1.30724e-08,5.17339e-12,-17250.5,14.6547], Tmin=(100,'K'), Tmax=(1147.61,'K')), NASAPolynomial(coeffs=[6.78908,0.0303597,-1.21262e-05,2.19944e-09,-1.50288e-13,-19105.8,-11.7332], Tmin=(1147.61,'K' ...
# Arrhenius(
#     A = (1e+14, 'cm^3/(mol*s)', '+|-', 1e+13),
#     n = 0,
#     Ea = (0, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (298, 'K'),
#     comment = 'Exact match found for rate rule (C_rad/H2/Cs;H_rad)',
# )
# Reaction(index=7, reactants=[Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], products=[Species(index=9, label="[H][H]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.42254,0.00028665,-4.14671e-07,4.27548e-10,-9.38119e-14,-1030.01,-3.86868], Tmin=(100,'K'), Tmax=(1962.85,'K')), NASAPolynomial(coeffs=[2.74219,0.00057954,1.97203e-07,-6.41094e-11,4.96003e-15,-552.264,0.409068], Tmin=(1962.85,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-8.59767,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(-8.59767,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H][H]")], transportData=TransportData(shapeIndex=1, epsilon=(315.951,'J/mol'), sigma=(2.92,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0.79,'angstroms^3'), rotrelaxcollnum=280.0, comment="""GRI-Mech"""), molecularWeight=(2.01588,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85))], kinetics=Arrhenius(A=(1.09e+11,'cm^3/(mol*s)'), n=0, Ea=(6.276,'kJ/mol'), T0=(1,'K'), Tmin=(278,'K'), Tmax=(372,'K'), comment="""Exact match found for rate rule (H_rad;H_rad)"""), pairs=[(Species(index=2, label="H", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[2.5,-1.91243e-12,2.45329e-15,-1.02377e-18,1.31369e-22,25472.7,-0.454534], Tmin=(100,'K'), Tmax=(4563.27,'K')), NASAPolynomial(coeffs=[2.50167,-1.43051e-06,4.6025e-10,-6.57826e-14,3.52412e-18,25471.2,-0.465139], Tmin=(4563.27,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(211.792,'kJ/mol'), comment="""Thermo library: KlippensteinH2O2"""), conformer=Conformer(E0=(211.792,'kJ/mol'), modes=[]), molecule=[Molecule(SMILES="[H]")], transportData=TransportData(shapeIndex=0, epsilon=(1205.6,'J/mol'), sigma=(2.05,'angstroms'), dipoleMoment=(0,'C*m'), polarizability=(0,'angstroms^3'), rotrelaxcollnum=0.0, comment="""GRI-Mech"""), molecularWeight=(1.00794,'amu'), energyTransferModel=SingleExponentialDown(alpha0=(3.5886,'kJ/mol'), T0=(300,'K'), n=0.85)), Species(index=9, label="[H][H]", thermo=NASA(polynomials=[NASAPolynomial(coeffs=[3.42254,0.00028665,-4.14671e-07,4.27548e-10,-9.38119e-14,-1030.01,-3.86868], Tmin=(100,'K'), Tmax=(1962.85,'K')), NASAPolynomial(coeffs=[2.74219,0.00057954,1.97203e-07,-6.41094e-11,4.96003e-15,-552.264,0.409068], Tmin=(1962.85,'K'), Tmax=(5000,'K'))], Tmin=(100,'K'), Tmax=(5000,'K'), E0=(-8.59767,'k ...
# Arrhenius(
#     A = (1.09e+11, 'cm^3/(mol*s)'),
#     n = 0,
#     Ea = (6.276, 'kJ/mol'),
#     T0 = (1, 'K'),
#     Tmin = (278, 'K'),
#     Tmax = (372, 'K'),
#     comment = 'Exact match found for rate rule (H_rad;H_rad)',
# )
